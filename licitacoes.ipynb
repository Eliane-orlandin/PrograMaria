# %% [markdown]
# <a href="https://colab.research.google.com/github/Eliane-orlandin/PrograMaria/blob/main/licitacoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/drive/MyDrive/ProgaMaria/licitacoes.csv',encoding="latin1", sep=";")

# %%
dados.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação'],
#       dtype='object')

# %%
dados[dados['Situação Licitação'] == 'Encerrado']
# Out:
#        Número Licitação  Código UG  \
# 3                 12018     925135
# 16                12018     130129
# 18                12018     135097
# 19                12018     152140
# 24                12018     153092
# ...                 ...        ...
# 15327         907662018     926130
# 15328         907732018     926130
# 15329         908252018     926130
# 15333         990922018     158139
# 15334         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 16       SUPERINT.REG.DE DESENV.DA LAV.CACAUEIRA/MT                         6
# 18                                     EMBRAPA CAFE                         7
# 19                    IFB - CAMPUS TAGUATINGA NORTE                         6
# 24                       BIBLIOTECA CENTRAL DA UFPE                         6
# ...

# %%
dados['Situação Licitação'].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %%
dados['Situação Licitação'].nunique()
# Out:
# 20

# %%
dados.groupby('Situação Licitação')['Situação Licitação'].nunique()
# Out:
# Situação Licitação
# Anulação                          1
# Divulgado                         1
# Encerrado                         1
# Evento de Adiamento Divulgado     1
# Evento de Adiamento Publicado     1
# Evento de Alteração Divulgad      1
# Evento de Alteração Publicad      1
# Evento de Alteração de Resul      1
# Evento de Anulação Publicado      1
# Evento de Habilitação Public      1
# Evento de Reabertura de Prazo     1
# Evento de Resultado de Julgame    1
# Evento de Retificação Divulg      1
# Evento de Retificação Public      1
# Evento de Revogação Publicad      1
# Evento de Suspensão Publicado     1
# Inválido                          1
# Publicado                         1
# Retificação                       1
# Revogação                         1
# Name: Situação Licitação, dtype: int64

# %%
# Identifique qual coluna possui valores faltantes
faltantes = dados.isnull().sum()
print(faltantes)
# Out:
# Número Licitação                0
# Código UG                       0
# Nome UG                         0
# Código Modalidade Compra        0
# Modalidade Compra               0
# Número Processo                 0
# Objeto                          0
# Situação Licitação              0
# Código Órgão Superior           0
# Nome Órgão Superior             0
# Código Órgão                    0
# Nome Órgão                      0
# UF                              0
# Município                       0
# Data Resultado Compra           0
# Data Abertura               10648
# Valor Licitação                 0
# dtype: int64

# %%
nulos = dados['Data Abertura'].isnull()
total_nulos = nulos.sum()
print(f"Total de valores nulos: {total_nulos}")
# Out:
# Total de valores nulos: 10648

# %%
#Identifique o tipo de dados desta coluna
tipo_dados = dados['Data Abertura'].dtypes
print(f"O tipo de dados dessa coluna é: {tipo_dados}")
# Out:
# O tipo de dados dessa coluna é: object

# %%
# Substituindo valores nulos por uma data inexistente
dados['Data Abertura'].fillna('00/00/0000', inplace=True)
print(dados['Data Abertura'])
# Out:
# 0        17/08/2016
# 1        00/00/0000
# 2        00/00/0000
# 3        30/11/2018
# 4        00/00/0000
#             ...
# 15331    26/11/2018
# 15332    00/00/0000
# 15333    00/00/0000
# 15334    00/00/0000
# 15335    00/00/0000
# Name: Data Abertura, Length: 15336, dtype: object

# %%
dados.isnull().sum()
# Out:
# Número Licitação            0
# Código UG                   0
# Nome UG                     0
# Código Modalidade Compra    0
# Modalidade Compra           0
# Número Processo             0
# Objeto                      0
# Situação Licitação          0
# Código Órgão Superior       0
# Nome Órgão Superior         0
# Código Órgão                0
# Nome Órgão                  0
# UF                          0
# Município                   0
# Data Resultado Compra       0
# Data Abertura               0
# Valor Licitação             0
# dtype: int64
